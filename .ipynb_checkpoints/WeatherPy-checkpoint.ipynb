# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The temperature is warmer between -40 to 20 degree latitude. This is as expected as 0 degree latitude is the equator.
# * There is no strong relationship between latitude and humidity as there is all level of humidity across all latitude.
# * There is also no strong relationship between latitude and cloudiness as there are cities with different level of cloudiness.
# * Most cities experience wind speed below 20 mph.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# import API key
import api_keys

# include citipy to determine city based on latitude and longitude
from citipy import citipy

# range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5f3486f0ccc7> in <module>
#       7
#       8 # import API key
# ----> 9 import api_keys
#      10
#      11 # include citipy to determine city based on latitude and longitude
#
# ModuleNotFoundError: No module named 'api_keys'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# identify nearest city for each latitude, longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# print the city count to confirm sufficient count
len(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# open WeatherMap API Key
api_key = api_keys.api_key

# perform API Calls
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# query URL
query_url = url + "appid=" + api_key + "&units=" + units + "&q="

# get weather data
print("Beginning Data Retrival")
print("------------------------------")

set_count = 1
record_count = 1
weather_data = {"City":[],"Cloudiness":[],"Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Max Temp":[],"Wind Speed": []}

for city in cities:
    weather_response = requests.get(query_url + city)
    weather_response_json = weather_response.json()
    
    if weather_response.status_code == 200:
        weather_data["City"].append(city)
        weather_data["Cloudiness"].append(weather_response_json["clouds"]["all"])
        weather_data["Country"].append(weather_response_json["sys"]["country"])
        weather_data["Date"].append(weather_response_json["dt"])
        weather_data["Humidity"].append(weather_response_json["main"]["humidity"])
        weather_data["Lat"].append(weather_response_json["coord"]["lat"])
        weather_data["Lng"].append(weather_response_json["coord"]["lon"])
        weather_data["Max Temp"].append(weather_response_json["main"]["temp_max"])
        weather_data["Wind Speed"].append(weather_response_json["wind"]["speed"])
        if record_count <= 50:
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1 
        else:
            record_count = 0
            set_count += 1
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1
    else:
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrival
# ------------------------------
# Processing Record 1 of Set 1 | carnarvon
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 1 | ilulissat
# Processing Record 3 of Set 1 | mitsamiouli
# Processing Record 4 of Set 1 | yenagoa
# Processing Record 5 of Set 1 | nioro
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 9 of Set 1 | douglas
# Processing Record 10 of Set 1 | lagoa
# Processing Record 11 of Set 1 | sungai udang
# Processing Record 12 of Set 1 | ulladulla
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | podolinec
# Processing Record 15 of Set 1 | yako
# City not found. Skipping...
# Processing Record 16 of Set 1 | lashio
# Processing Record 17 of Set 1 | los llanos de aridane
# Processing Record 18 of Set 1 | sangamner
# Processing Record 19 of Set 1 | naryan-mar
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | tateyama
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | dunedin
# Processing Record 25 of Set 1 | port blair
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | chuy
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | lere
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | loreto
# Processing Record 36 of Set 1 | makinsk
# Processing Record 37 of Set 1 | san lawrenz
# Processing Record 38 of Set 1 | shirokiy
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | ambulu
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | pingliang
# Processing Record 46 of Set 1 | khatanga
# City not found. Skipping...
# Processing Record 47 of Set 1 | mount gambier
# Processing Record 48 of Set 1 | keti bandar
# City not found. Skipping...
# Processing Record 49 of Set 1 | vila franca do campo
# Processing Record 50 of Set 1 | muros
# Processing Record 0 of Set 2 | sangueya
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | acajutla
# Processing Record 3 of Set 2 | camacha
# Processing Record 4 of Set 2 | borogontsy
# Processing Record 5 of Set 2 | acapulco
# Processing Record 6 of Set 2 | lixourion
# City not found. Skipping...
# Processing Record 7 of Set 2 | saint-philippe
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | cordoba
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | aklavik
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | san cristobal
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | lahaina
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | muisne
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | luderitz
# Processing Record 22 of Set 2 | villarrobledo
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | kalmunai
# Processing Record 25 of Set 2 | manado
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | angoche
# Processing Record 30 of Set 2 | fairbanks
# Processing Record 31 of Set 2 | atuona
# City not found. Skipping...
# Processing Record 32 of Set 2 | qinhuangdao
# Processing Record 33 of Set 2 | alamogordo
# Processing Record 34 of Set 2 | luau
# Processing Record 35 of Set 2 | sholokhovskiy
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | esmeraldas
# Processing Record 38 of Set 2 | saint-pierre
# Processing Record 39 of Set 2 | pangoa
# City not found. Skipping...
# Processing Record 40 of Set 2 | umm lajj
# City not found. Skipping...
# Processing Record 41 of Set 2 | rio grande
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | mattru
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | paris
# Processing Record 47 of Set 2 | banda aceh
# City not found. Skipping...
# Processing Record 48 of Set 2 | havoysund
# Processing Record 49 of Set 2 | komsomolskiy
# Processing Record 50 of Set 2 | berlevag
# Processing Record 0 of Set 3 | thunder bay
# Processing Record 1 of Set 3 | geraldton
# Processing Record 2 of Set 3 | coahuayana
# Processing Record 3 of Set 3 | mayumba
# City not found. Skipping...
# Processing Record 4 of Set 3 | kang
# City not found. Skipping...
# Processing Record 5 of Set 3 | coquimbo
# Processing Record 6 of Set 3 | skagen
# Processing Record 7 of Set 3 | belmonte
# Processing Record 8 of Set 3 | zemio
# Processing Record 9 of Set 3 | magistralnyy
# Processing Record 10 of Set 3 | taksimo
# Processing Record 11 of Set 3 | yerbogachen
# Processing Record 12 of Set 3 | cockburn town
# Processing Record 13 of Set 3 | tessalit
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 3 | busselton
# City not found. Skipping...
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | akhnur
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | la romana
# Processing Record 21 of Set 3 | walvis bay
# Processing Record 22 of Set 3 | portland
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | sibolga
# Processing Record 25 of Set 3 | makakilo city
# City not found. Skipping...
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | lysva
# Processing Record 28 of Set 3 | narsaq
# City not found. Skipping...
# Processing Record 29 of Set 3 | ilinskiy
# Processing Record 30 of Set 3 | greenville
# City not found. Skipping...
# Processing Record 31 of Set 3 | hithadhoo
# City not found. Skipping...
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | georgetown
# Processing Record 34 of Set 3 | yar-sale
# Processing Record 35 of Set 3 | samarai
# Processing Record 36 of Set 3 | nanortalik
# Processing Record 37 of Set 3 | mar del plata
# Processing Record 38 of Set 3 | sokoni
# Processing Record 39 of Set 3 | porto torres
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | adrar
# Processing Record 42 of Set 3 | labuhan
# Processing Record 43 of Set 3 | red bluff
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | fallon
# Processing Record 46 of Set 3 | carbondale
# City not found. Skipping...
# Processing Record 47 of Set 3 | boddam
# Processing Record 48 of Set 3 | christchurch
# Processing Record 49 of Set 3 | sinnamary
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 0 of Set 4 | barrow
# Processing Record 1 of Set 4 | deputatskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | zhezkazgan
# Processing Record 3 of Set 4 | sola
# Processing Record 4 of Set 4 | kumta
# Processing Record 5 of Set 4 | champerico
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | aquiraz
# Processing Record 8 of Set 4 | perth
# Processing Record 9 of Set 4 | korhogo
# City not found. Skipping...
# Processing Record 10 of Set 4 | guerrero negro
# Processing Record 11 of Set 4 | yokadouma
# Processing Record 12 of Set 4 | balakovo
# Processing Record 13 of Set 4 | la ronge
# Processing Record 14 of Set 4 | hambantota
# Processing Record 15 of Set 4 | ambilobe
# Processing Record 16 of Set 4 | imbituba
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | andover
# Processing Record 19 of Set 4 | westport
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | fukue
# Processing Record 22 of Set 4 | lazurne
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | baruun-urt
# Processing Record 25 of Set 4 | coihaique
# Processing Record 26 of Set 4 | bilma
# City not found. Skipping...
# Processing Record 27 of Set 4 | man
# Processing Record 28 of Set 4 | maldonado
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | jian
# Processing Record 31 of Set 4 | slidell
# Processing Record 32 of Set 4 | thompson
# City not found. Skipping...
# Processing Record 33 of Set 4 | huilong
# Processing Record 34 of Set 4 | rudnichnyy
# Processing Record 35 of Set 4 | naerbo
# Processing Record 36 of Set 4 | barcelos
# Processing Record 37 of Set 4 | muroto
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | fare
# Processing Record 40 of Set 4 | blythe
# Processing Record 41 of Set 4 | jumla
# Processing Record 42 of Set 4 | saint-claude
# Processing Record 43 of Set 4 | klyuchi
# Processing Record 44 of Set 4 | ati
# Processing Record 45 of Set 4 | moron
# Processing Record 46 of Set 4 | boende
# City not found. Skipping...
# Processing Record 47 of Set 4 | ballina
# Processing Record 48 of Set 4 | mackay
# Processing Record 49 of Set 4 | tocopilla
# Processing Record 50 of Set 4 | sarishabari
# Processing Record 0 of Set 5 | westfield
# Processing Record 1 of Set 5 | aketi
# Processing Record 2 of Set 5 | marabba
# City not found. Skipping...
# Processing Record 3 of Set 5 | cherskiy
# Processing Record 4 of Set 5 | grimstad
# Processing Record 5 of Set 5 | srednekolymsk
# Processing Record 6 of Set 5 | birao
# Processing Record 7 of Set 5 | nantucket
# Processing Record 8 of Set 5 | kruisfontein
# City not found. Skipping...
# Processing Record 9 of Set 5 | tori
# Processing Record 10 of Set 5 | levin
# Processing Record 11 of Set 5 | qasigiannguit
# Processing Record 12 of Set 5 | novorozhdestvenskaya
# Processing Record 13 of Set 5 | yulara
# City not found. Skipping...
# Processing Record 14 of Set 5 | allanridge
# Processing Record 15 of Set 5 | zheleznodorozhnyy
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | vostok
# Processing Record 18 of Set 5 | vitina
# Processing Record 19 of Set 5 | damaturu
# Processing Record 20 of Set 5 | chase
# Processing Record 21 of Set 5 | qaqortoq
# Processing Record 22 of Set 5 | sao joao da barra
# Processing Record 23 of Set 5 | beisfjord
# Processing Record 24 of Set 5 | ankang
# Processing Record 25 of Set 5 | mahanoro
# Processing Record 26 of Set 5 | mount isa
# Processing Record 27 of Set 5 | zhanaozen
# Processing Record 28 of Set 5 | ishigaki
# Processing Record 29 of Set 5 | laguna
# Processing Record 30 of Set 5 | terrace
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 5 | ahuimanu
# Processing Record 32 of Set 5 | uribia
# Processing Record 33 of Set 5 | nizhnevartovsk
# Processing Record 34 of Set 5 | tromso
# Processing Record 35 of Set 5 | serrinha
# Processing Record 36 of Set 5 | zaysan
# Processing Record 37 of Set 5 | hirara
# City not found. Skipping...
# Processing Record 38 of Set 5 | pitimbu
# Processing Record 39 of Set 5 | sioux lookout
# Processing Record 40 of Set 5 | ayna
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | artigas
# Processing Record 43 of Set 5 | port lincoln
# Processing Record 44 of Set 5 | phan thiet
# Processing Record 45 of Set 5 | igarka
# Processing Record 46 of Set 5 | nemuro
# Processing Record 47 of Set 5 | pocone
# Processing Record 48 of Set 5 | yamada
# Processing Record 49 of Set 5 | ola
# Processing Record 50 of Set 5 | half moon bay
# Processing Record 0 of Set 6 | awbari
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | erenhot
# Processing Record 3 of Set 6 | kaeo
# Processing Record 4 of Set 6 | calvinia
# Processing Record 5 of Set 6 | wewak
# Processing Record 6 of Set 6 | phonhong
# Processing Record 7 of Set 6 | henties bay
# Processing Record 8 of Set 6 | torbay
# Processing Record 9 of Set 6 | chengdu
# Processing Record 10 of Set 6 | buala
# Processing Record 11 of Set 6 | honiara
# Processing Record 12 of Set 6 | amapa
# Processing Record 13 of Set 6 | woodstock
# Processing Record 14 of Set 6 | balakhta
# Processing Record 15 of Set 6 | brae
# Processing Record 16 of Set 6 | faranah
# Processing Record 17 of Set 6 | vila velha
# Processing Record 18 of Set 6 | beipiao
# Processing Record 19 of Set 6 | serebryanyy bor
# City not found. Skipping...
# Processing Record 20 of Set 6 | pacific grove
# Processing Record 21 of Set 6 | dalby
# Processing Record 22 of Set 6 | shimoda
# Processing Record 23 of Set 6 | chastyye
# Processing Record 24 of Set 6 | tommot
# Processing Record 25 of Set 6 | grand gaube
# Processing Record 26 of Set 6 | duminichi
# Processing Record 27 of Set 6 | akdepe
# Processing Record 28 of Set 6 | reconquista
# City not found. Skipping...
# Processing Record 29 of Set 6 | porto novo
# Processing Record 30 of Set 6 | kyshtovka
# Processing Record 31 of Set 6 | umtata
# Processing Record 32 of Set 6 | tigil
# Processing Record 33 of Set 6 | atar
# Processing Record 34 of Set 6 | bambous virieux
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | eureka
# Processing Record 37 of Set 6 | charlottesville
# Processing Record 38 of Set 6 | chokurdakh
# City not found. Skipping...
# Processing Record 39 of Set 6 | tezu
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | inuvik
# Processing Record 42 of Set 6 | ribeira grande
# Processing Record 43 of Set 6 | rio brilhante
# Processing Record 44 of Set 6 | puerto leguizamo
# Processing Record 45 of Set 6 | seoul
# Processing Record 46 of Set 6 | togur
# Processing Record 47 of Set 6 | puerto maldonado
# Processing Record 48 of Set 6 | carbonear
# Processing Record 49 of Set 6 | zhigalovo
# Processing Record 50 of Set 6 | qena
# City not found. Skipping...
# Processing Record 0 of Set 7 | hofn
# Processing Record 1 of Set 7 | northam
# Processing Record 2 of Set 7 | kununurra
# City not found. Skipping...
# Processing Record 3 of Set 7 | japaratuba
# Processing Record 4 of Set 7 | baturaja
# Processing Record 5 of Set 7 | ancud
# Processing Record 6 of Set 7 | nortelandia
# Processing Record 7 of Set 7 | kansanshi
# Processing Record 8 of Set 7 | bichena
# Processing Record 9 of Set 7 | amboasary
# Processing Record 10 of Set 7 | tabuk
# City not found. Skipping...
# Processing Record 11 of Set 7 | boshnyakovo
# Processing Record 12 of Set 7 | hualmay
# Processing Record 13 of Set 7 | camocim
# Processing Record 14 of Set 7 | borda da mata
# Processing Record 15 of Set 7 | gboko
# Processing Record 16 of Set 7 | taseyevo
# Processing Record 17 of Set 7 | hilo
# Processing Record 18 of Set 7 | san juan
# Processing Record 19 of Set 7 | mersing
# Processing Record 20 of Set 7 | omsukchan
# Processing Record 21 of Set 7 | poya
# Processing Record 22 of Set 7 | hukuntsi
# Processing Record 23 of Set 7 | kargopol
# Processing Record 24 of Set 7 | zapolyarnyy
# Processing Record 25 of Set 7 | obama
# Processing Record 26 of Set 7 | rolla
# Processing Record 27 of Set 7 | valreas
# Processing Record 28 of Set 7 | asha
# Processing Record 29 of Set 7 | ulaanbaatar
# Processing Record 30 of Set 7 | west bay
# Processing Record 31 of Set 7 | sundumbili
# Processing Record 32 of Set 7 | haines junction
# Processing Record 33 of Set 7 | pemba
# Processing Record 34 of Set 7 | ormara
# Processing Record 35 of Set 7 | pevek
# Processing Record 36 of Set 7 | avera
# Processing Record 37 of Set 7 | suzhou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 7 | zhigansk
# Processing Record 39 of Set 7 | fernandez
# Processing Record 40 of Set 7 | batiano
# Processing Record 41 of Set 7 | havelock
# Processing Record 42 of Set 7 | kedrovyy
# Processing Record 43 of Set 7 | enumclaw
# Processing Record 44 of Set 7 | copiapo
# Processing Record 45 of Set 7 | sattahip
# City not found. Skipping...
# Processing Record 46 of Set 7 | hervey bay
# Processing Record 47 of Set 7 | kaberamaido
# Processing Record 48 of Set 7 | norman wells
# Processing Record 49 of Set 7 | terra santa
# Processing Record 50 of Set 7 | salisbury
# Processing Record 0 of Set 8 | shingu
# City not found. Skipping...
# Processing Record 1 of Set 8 | hami
# Processing Record 2 of Set 8 | ust-nera
# Processing Record 3 of Set 8 | sur
# Processing Record 4 of Set 8 | kurunegala
# Processing Record 5 of Set 8 | fergus
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | sorong
# Processing Record 8 of Set 8 | port-gentil
# Processing Record 9 of Set 8 | luganville
# Processing Record 10 of Set 8 | almeirim
# Processing Record 11 of Set 8 | barstow
# Processing Record 12 of Set 8 | cacoal
# Processing Record 13 of Set 8 | kautokeino
# Processing Record 14 of Set 8 | lavrentiya
# Processing Record 15 of Set 8 | thinadhoo
# Processing Record 16 of Set 8 | tautira
# City not found. Skipping...
# Processing Record 17 of Set 8 | sainte-suzanne
# Processing Record 18 of Set 8 | kluczbork
# Processing Record 19 of Set 8 | mahbubnagar
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | holden
# Processing Record 22 of Set 8 | halifax
# Processing Record 23 of Set 8 | airai
# Processing Record 24 of Set 8 | krasnorechenskiy
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | vanavara
# Processing Record 27 of Set 8 | lahij
# Processing Record 28 of Set 8 | mulege
# Processing Record 29 of Set 8 | campoverde
# Processing Record 30 of Set 8 | mecca
# City not found. Skipping...
# Processing Record 31 of Set 8 | genhe
# Processing Record 32 of Set 8 | rincon
# Processing Record 33 of Set 8 | aurillac
# Processing Record 34 of Set 8 | faya
# Processing Record 35 of Set 8 | haukipudas
# Processing Record 36 of Set 8 | aiken
# Processing Record 37 of Set 8 | swan hill
# Processing Record 38 of Set 8 | bathsheba
# Processing Record 39 of Set 8 | broome
# Processing Record 40 of Set 8 | dasoguz
# Processing Record 41 of Set 8 | ialibu
# Processing Record 42 of Set 8 | comodoro rivadavia
# Processing Record 43 of Set 8 | bowen
# Processing Record 44 of Set 8 | ponta delgada
# Processing Record 45 of Set 8 | sao filipe
# Processing Record 46 of Set 8 | odesskoye
# Processing Record 47 of Set 8 | ventspils
# Processing Record 48 of Set 8 | manacapuru
# Processing Record 49 of Set 8 | iqaluit
# Processing Record 50 of Set 8 | livingston
# Processing Record 0 of Set 9 | weymouth
# Processing Record 1 of Set 9 | vigeland
# Processing Record 2 of Set 9 | tamandare
# City not found. Skipping...
# Processing Record 3 of Set 9 | bandeirantes
# Processing Record 4 of Set 9 | college
# Processing Record 5 of Set 9 | jati
# Processing Record 6 of Set 9 | eyl
# Processing Record 7 of Set 9 | yola
# Processing Record 8 of Set 9 | itoman
# Processing Record 9 of Set 9 | bethel
# Processing Record 10 of Set 9 | lasa
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 9 | alofi
# Processing Record 12 of Set 9 | kaura namoda
# Processing Record 13 of Set 9 | namatanai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 14 of Set 9 | lata
# Processing Record 15 of Set 9 | turukhansk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 9 | kommunisticheskiy
# Processing Record 17 of Set 9 | ilebo
# Processing Record 18 of Set 9 | svetlogorsk
# Processing Record 19 of Set 9 | saldanha
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | formosa do rio preto
# Processing Record 22 of Set 9 | metro
# Processing Record 23 of Set 9 | souillac
# Processing Record 24 of Set 9 | isangel
# Processing Record 25 of Set 9 | san joaquin
# Processing Record 26 of Set 9 | lakes entrance
# Processing Record 27 of Set 9 | mercedes
# Processing Record 28 of Set 9 | sangmelima
# City not found. Skipping...
# Processing Record 29 of Set 9 | aksu
# Processing Record 30 of Set 9 | biloela
# Processing Record 31 of Set 9 | batagay
# Processing Record 32 of Set 9 | prabumulih
# Processing Record 33 of Set 9 | port macquarie
# Processing Record 34 of Set 9 | sisophon
# Processing Record 35 of Set 9 | gat
# Processing Record 36 of Set 9 | kailua
# Processing Record 37 of Set 9 | kolosovka
# City not found. Skipping...
# Processing Record 38 of Set 9 | ahipara
# City not found. Skipping...
# Processing Record 39 of Set 9 | mehamn
# Processing Record 40 of Set 9 | harlingen
# Processing Record 41 of Set 9 | vao
# Processing Record 42 of Set 9 | grindavik
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | canutama
# Processing Record 45 of Set 9 | gerash
# Processing Record 46 of Set 9 | nyagan
# Processing Record 47 of Set 9 | itaituba
# City not found. Skipping...
# Processing Record 48 of Set 9 | alencon
# Processing Record 49 of Set 9 | gigmoto
# Processing Record 50 of Set 9 | phetchabun
# Processing Record 0 of Set 10 | yarada
# Processing Record 1 of Set 10 | mayo
# Processing Record 2 of Set 10 | khandyga
# Processing Record 3 of Set 10 | novikovo
# Processing Record 4 of Set 10 | viedma
# Processing Record 5 of Set 10 | linjiang
# Processing Record 6 of Set 10 | sambava
# City not found. Skipping...
# Processing Record 7 of Set 10 | beloha
# Processing Record 8 of Set 10 | gumdag
# Processing Record 9 of Set 10 | luangwa
# Processing Record 10 of Set 10 | koumra
# Processing Record 11 of Set 10 | oktyabrskiy
# Processing Record 12 of Set 10 | kanashevo
# Processing Record 13 of Set 10 | basco
# Processing Record 14 of Set 10 | lira
# Processing Record 15 of Set 10 | wadi musa
# City not found. Skipping...
# Processing Record 16 of Set 10 | sira
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 10 | naze
# City not found. Skipping...
# Processing Record 18 of Set 10 | touros
# Processing Record 19 of Set 10 | hamilton
# Processing Record 20 of Set 10 | kholm-zhirkovskiy
# City not found. Skipping...
# Processing Record 21 of Set 10 | jalu
# Processing Record 22 of Set 10 | del rio
# Processing Record 23 of Set 10 | kiunga
# Processing Record 24 of Set 10 | jiangyou
# City not found. Skipping...
# Processing Record 25 of Set 10 | aitape
# Processing Record 26 of Set 10 | jabinyanah
# Processing Record 27 of Set 10 | clyde river
# Processing Record 28 of Set 10 | binika
# Processing Record 29 of Set 10 | olga
# Processing Record 30 of Set 10 | marigot
# City not found. Skipping...
# Processing Record 31 of Set 10 | caravelas
# Processing Record 32 of Set 10 | suluq
# Processing Record 33 of Set 10 | aykhal
# Processing Record 34 of Set 10 | impfondo
# Processing Record 35 of Set 10 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 36 of Set 10 | araceli
# Processing Record 37 of Set 10 | cap-aux-meules
# Processing Record 38 of Set 10 | kharp
# Processing Record 39 of Set 10 | ubaitaba
# Processing Record 40 of Set 10 | kholodnyy
# Processing Record 41 of Set 10 | amuntai
# Processing Record 42 of Set 10 | clifton
# Processing Record 43 of Set 10 | killarney
# Processing Record 44 of Set 10 | uliesti
# Processing Record 45 of Set 10 | rabo de peixe
# Processing Record 46 of Set 10 | balkanabat
# Processing Record 47 of Set 10 | manyana
# Processing Record 48 of Set 10 | kysyl-syr
# Processing Record 49 of Set 10 | beringovskiy
# Processing Record 50 of Set 10 | syamzha
# Processing Record 0 of Set 11 | mollendo
# Processing Record 1 of Set 11 | cassilandia
# Processing Record 2 of Set 11 | izumo
# City not found. Skipping...
# Processing Record 3 of Set 11 | namibe
# Processing Record 4 of Set 11 | victor harbor
# Processing Record 5 of Set 11 | noumea
# Processing Record 6 of Set 11 | dhangadhi
# Processing Record 7 of Set 11 | luena
# Processing Record 8 of Set 11 | shache
# Processing Record 9 of Set 11 | oneonta
# Processing Record 10 of Set 11 | whitehorse
# Processing Record 11 of Set 11 | joshimath
# Processing Record 12 of Set 11 | marienburg
# Processing Record 13 of Set 11 | chimbote
# City not found. Skipping...
# Processing Record 14 of Set 11 | artyom
# City not found. Skipping...
# Processing Record 15 of Set 11 | voh
# Processing Record 16 of Set 11 | dimitrovgrad
# Processing Record 17 of Set 11 | broken hill
# Processing Record 18 of Set 11 | saint-joseph
# Processing Record 19 of Set 11 | pimenta bueno
# Processing Record 20 of Set 11 | ha giang
# Processing Record 21 of Set 11 | bandarbeyla
# Processing Record 22 of Set 11 | paso de carrasco
# Processing Record 23 of Set 11 | ginda
# City not found. Skipping...
# Processing Record 24 of Set 11 | caucaia
# Processing Record 25 of Set 11 | oum hadjer
# Processing Record 26 of Set 11 | mogadouro
# Processing Record 27 of Set 11 | bouna
# Processing Record 28 of Set 11 | ust-tsilma
# City not found. Skipping...
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# convert to data frame 
weather_df = pd.DataFrame(weather_data)

# display data frame
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0    carnarvon           8      ZA  1551281884        14 -30.97  22.13
# 1    ilulissat           5      GL  1551279000        52  69.22 -51.10
# 2  mitsamiouli          40      KM  1551279600        70 -11.38  43.28
# 3      yenagoa          24      NG  1551282369        90   4.92   6.26
# 4        nioro          12      GM  1551281969        19  13.79 -15.05
#
#    Max Temp  Wind Speed
# 0     78.81       11.59
# 1     17.60        1.12
# 2     86.00        3.36
# 3     83.89        6.89
# 4     88.93       14.38

# %%
weather_df.count()
# Out:
# City          538
# Cloudiness    538
# Country       538
# Date          538
# Humidity      538
# Lat           538
# Lng           538
# Max Temp      538
# Wind Speed    538
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# export the city data into csv
weather_df.to_csv("output/weather_data.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# set y limits and grids
plt.ylim(0,105)
plt.grid(True)

# save figure
plt.savefig("images/LattitudeVsTemp.png")

# display the figure
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Humidity"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# set y limits and grids
plt.ylim(0,105)
plt.grid(True)

# save figure
plt.savefig("images/LatitudeVsHumidity.png")

# display the figure
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# set y limits and grids
plt.ylim(0,105)
plt.grid(True)

# save figure
plt.savefig("images/LatitudeVsCloudiness.png")

# display the figure
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# set y limits and grids
plt.ylim(0,35)
plt.grid(True)

# save figure
plt.savefig("images/LatitudeVsWindSpeed.png")

# display the figure
plt.show()
