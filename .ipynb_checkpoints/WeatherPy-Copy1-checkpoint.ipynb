# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * The temperature is warmer between -40 to 20 degree latitude. This is as expected as 0 degree latitude is the equator.
# * There is no strong relationship between latitude and humidity as there is all level of humidity across all latitude.
# * There is also no strong relationship between latitude and cloudiness as there are cities with different level of cloudiness.
# * Most cities experience wind speed below 20 mph.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# import API key
import api_keys

# include citipy to determine city based on latitude and longitude
from citipy import citipy

# range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# identify nearest city for each latitude, longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# print the city count to confirm sufficient count
len(cities)
# Out:
# 575

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# open WeatherMap API Key
api_key = api_keys.api_key

# perform API Calls
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# query URL
query_url = url + "appid=" + api_key + "&units=" + units + "&q="

# get weather data
print("Beginning Data Retrival")
print("------------------------------")

set_count = 1
record_count = 1
weather_data = {"City":[],"Cloudiness":[],"Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Max Temp":[],"Wind Speed": []}

for city in cities:
    weather_response = requests.get(query_url + city)
    weather_response_json = weather_response.json()
    
    if weather_response.status_code == 200:
        weather_data["City"].append(city)
        weather_data["Cloudiness"].append(weather_response_json["clouds"]["all"])
        weather_data["Country"].append(weather_response_json["sys"]["country"])
        weather_data["Date"].append(weather_response_json["dt"])
        weather_data["Humidity"].append(weather_response_json["main"]["humidity"])
        weather_data["Lat"].append(weather_response_json["coord"]["lat"])
        weather_data["Lng"].append(weather_response_json["coord"]["lon"])
        weather_data["Max Temp"].append(weather_response_json["main"]["temp_max"])
        weather_data["Wind Speed"].append(weather_response_json["wind"]["speed"])
        if record_count <= 50:
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1 
        else:
            record_count = 0
            set_count += 1
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1
    else:
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrival
# ------------------------------
# Processing Record 1 of Set 1 | yichun
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | byron bay
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | elkhart
# Processing Record 7 of Set 1 | wasilla
# Processing Record 8 of Set 1 | hamilton
# Processing Record 9 of Set 1 | hwange
# Processing Record 10 of Set 1 | kaitangata
# Processing Record 11 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 12 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | gushikawa
# Processing Record 15 of Set 1 | kosa
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 19 of Set 1 | nhulunbuy
# City not found. Skipping...
# Processing Record 20 of Set 1 | hilo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | lavrentiya
# Processing Record 23 of Set 1 | ancud
# Processing Record 24 of Set 1 | yumen
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | isangel
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | namibe
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | jiayuguan
# Processing Record 34 of Set 1 | van
# Processing Record 35 of Set 1 | ambulu
# Processing Record 36 of Set 1 | kedrovyy
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | prince rupert
# Processing Record 40 of Set 1 | ullapool
# City not found. Skipping...
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | ovsyanka
# Processing Record 43 of Set 1 | hovd
# City not found. Skipping...
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | san rafael
# Processing Record 48 of Set 1 | peniche
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | albany
# City not found. Skipping...
# Processing Record 0 of Set 2 | vila franca do campo
# Processing Record 1 of Set 2 | sept-iles
# Processing Record 2 of Set 2 | torbay
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | jalor
# Processing Record 7 of Set 2 | chokurdakh
# Processing Record 8 of Set 2 | chuy
# Processing Record 9 of Set 2 | buchanan
# Processing Record 10 of Set 2 | morgantown
# City not found. Skipping...
# Processing Record 11 of Set 2 | bitung
# Processing Record 12 of Set 2 | the valley
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | saint-augustin
# Processing Record 15 of Set 2 | comodoro rivadavia
# Processing Record 16 of Set 2 | komsomolskiy
# Processing Record 17 of Set 2 | mareeba
# Processing Record 18 of Set 2 | melfi
# Processing Record 19 of Set 2 | hofn
# Processing Record 20 of Set 2 | verkhoyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | victoria
# Processing Record 22 of Set 2 | san patricio
# Processing Record 23 of Set 2 | laguna
# Processing Record 24 of Set 2 | marrakesh
# City not found. Skipping...
# Processing Record 25 of Set 2 | aksarka
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | new norfolk
# City not found. Skipping...
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | ust-kuyga
# Processing Record 31 of Set 2 | pevek
# Processing Record 32 of Set 2 | kavieng
# Processing Record 33 of Set 2 | klaksvik
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | samarinda
# Processing Record 36 of Set 2 | gobabis
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | abbeville
# Processing Record 39 of Set 2 | genhe
# Processing Record 40 of Set 2 | burnie
# Processing Record 41 of Set 2 | nacala
# Processing Record 42 of Set 2 | naze
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | mount gambier
# Processing Record 45 of Set 2 | samarai
# Processing Record 46 of Set 2 | nome
# Processing Record 47 of Set 2 | codrington
# City not found. Skipping...
# Processing Record 48 of Set 2 | masvingo
# Processing Record 49 of Set 2 | weston
# Processing Record 50 of Set 2 | vestmannaeyjar
# Processing Record 0 of Set 3 | murdochville
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | lata
# Processing Record 4 of Set 3 | lorengau
# Processing Record 5 of Set 3 | dunedin
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | pringsewu
# City not found. Skipping...
# Processing Record 8 of Set 3 | busselton
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | deputatskiy
# Processing Record 12 of Set 3 | denpasar
# City not found. Skipping...
# Processing Record 13 of Set 3 | broken hill
# Processing Record 14 of Set 3 | meulaboh
# Processing Record 15 of Set 3 | aktau
# Processing Record 16 of Set 3 | chapais
# Processing Record 17 of Set 3 | zaysan
# Processing Record 18 of Set 3 | almaznyy
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | castro
# City not found. Skipping...
# Processing Record 21 of Set 3 | tura
# Processing Record 22 of Set 3 | saint george
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | zhezkazgan
# Processing Record 25 of Set 3 | arkadak
# Processing Record 26 of Set 3 | khani
# Processing Record 27 of Set 3 | sobolevo
# Processing Record 28 of Set 3 | miraflores
# Processing Record 29 of Set 3 | vanavara
# Processing Record 30 of Set 3 | port hawkesbury
# Processing Record 31 of Set 3 | fare
# Processing Record 32 of Set 3 | zakharovo
# Processing Record 33 of Set 3 | vao
# Processing Record 34 of Set 3 | antalaha
# Processing Record 35 of Set 3 | mataram
# Processing Record 36 of Set 3 | hermanus
# City not found. Skipping...
# Processing Record 37 of Set 3 | kununurra
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | hualmay
# Processing Record 40 of Set 3 | san pedro
# Processing Record 41 of Set 3 | yatou
# Processing Record 42 of Set 3 | urubicha
# City not found. Skipping...
# Processing Record 43 of Set 3 | evensk
# Processing Record 44 of Set 3 | port hardy
# Processing Record 45 of Set 3 | pauini
# Processing Record 46 of Set 3 | provideniya
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | souillac
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 0 of Set 4 | beloha
# Processing Record 1 of Set 4 | ginir
# Processing Record 2 of Set 4 | plettenberg bay
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | springdale
# Processing Record 5 of Set 4 | husavik
# Processing Record 6 of Set 4 | cururupu
# Processing Record 7 of Set 4 | solnechnyy
# Processing Record 8 of Set 4 | udaipur
# City not found. Skipping...
# Processing Record 9 of Set 4 | huanren
# Processing Record 10 of Set 4 | moerai
# Processing Record 11 of Set 4 | avera
# Processing Record 12 of Set 4 | puerto carreno
# Processing Record 13 of Set 4 | rognan
# Processing Record 14 of Set 4 | kirakira
# Processing Record 15 of Set 4 | buta
# Processing Record 16 of Set 4 | cabedelo
# Processing Record 17 of Set 4 | waingapu
# Processing Record 18 of Set 4 | tuy hoa
# Processing Record 19 of Set 4 | longyearbyen
# City not found. Skipping...
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | boquira
# Processing Record 22 of Set 4 | dawei
# Processing Record 23 of Set 4 | raudeberg
# Processing Record 24 of Set 4 | corinto
# Processing Record 25 of Set 4 | hambantota
# Processing Record 26 of Set 4 | pueblo nuevo
# Processing Record 27 of Set 4 | ludvika
# Processing Record 28 of Set 4 | ponta do sol
# Processing Record 29 of Set 4 | christchurch
# Processing Record 30 of Set 4 | bilma
# Processing Record 31 of Set 4 | severo-kurilsk
# Processing Record 32 of Set 4 | kanye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 4 | mitsamiouli
# Processing Record 34 of Set 4 | tombouctou
# Processing Record 35 of Set 4 | oranjemund
# Processing Record 36 of Set 4 | ostrovnoy
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | pulwama
# Processing Record 39 of Set 4 | yerbogachen
# Processing Record 40 of Set 4 | bluff
# City not found. Skipping...
# Processing Record 41 of Set 4 | biak
# City not found. Skipping...
# Processing Record 42 of Set 4 | anchorage
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 4 | santa luzia
# Processing Record 44 of Set 4 | bredasdorp
# City not found. Skipping...
# Processing Record 45 of Set 4 | skjervoy
# Processing Record 46 of Set 4 | batemans bay
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | kushima
# Processing Record 49 of Set 4 | coos bay
# Processing Record 50 of Set 4 | teopantlan
# Processing Record 0 of Set 5 | san lorenzo
# Processing Record 1 of Set 5 | humberto de campos
# City not found. Skipping...
# Processing Record 2 of Set 5 | whitehorse
# Processing Record 3 of Set 5 | gigmoto
# City not found. Skipping...
# Processing Record 4 of Set 5 | road town
# Processing Record 5 of Set 5 | hasaki
# City not found. Skipping...
# Processing Record 6 of Set 5 | vostok
# Processing Record 7 of Set 5 | vardo
# Processing Record 8 of Set 5 | mount isa
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | khatanga
# Processing Record 13 of Set 5 | tautira
# City not found. Skipping...
# Processing Record 14 of Set 5 | cayenne
# Processing Record 15 of Set 5 | sao joao da barra
# Processing Record 16 of Set 5 | henties bay
# Processing Record 17 of Set 5 | kieta
# Processing Record 18 of Set 5 | ouidah
# Processing Record 19 of Set 5 | ypsilanti
# Processing Record 20 of Set 5 | burgeo
# Processing Record 21 of Set 5 | takeo
# Processing Record 22 of Set 5 | porto-vecchio
# Processing Record 23 of Set 5 | ossora
# Processing Record 24 of Set 5 | taksimo
# Processing Record 25 of Set 5 | kattivakkam
# Processing Record 26 of Set 5 | adrar
# Processing Record 27 of Set 5 | vung tau
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | launceston
# City not found. Skipping...
# Processing Record 30 of Set 5 | tarakan
# Processing Record 31 of Set 5 | tias
# Processing Record 32 of Set 5 | praia
# Processing Record 33 of Set 5 | atasu
# Processing Record 34 of Set 5 | rocha
# Processing Record 35 of Set 5 | dongkan
# Processing Record 36 of Set 5 | synya
# Processing Record 37 of Set 5 | nabire
# Processing Record 38 of Set 5 | tara
# City not found. Skipping...
# Processing Record 39 of Set 5 | kyren
# Processing Record 40 of Set 5 | goderich
# Processing Record 41 of Set 5 | grindavik
# Processing Record 42 of Set 5 | kalmunai
# Processing Record 43 of Set 5 | vanino
# Processing Record 44 of Set 5 | nipawin
# City not found. Skipping...
# Processing Record 45 of Set 5 | homer
# Processing Record 46 of Set 5 | brae
# Processing Record 47 of Set 5 | guerrero negro
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | tucuman
# Processing Record 50 of Set 5 | kodiak
# Processing Record 0 of Set 6 | viedma
# Processing Record 1 of Set 6 | ahipara
# Processing Record 2 of Set 6 | jining
# Processing Record 3 of Set 6 | gaoua
# Processing Record 4 of Set 6 | tasiilaq
# Processing Record 5 of Set 6 | shingu
# City not found. Skipping...
# Processing Record 6 of Set 6 | ribeira grande
# Processing Record 7 of Set 6 | honningsvag
# Processing Record 8 of Set 6 | port augusta
# Processing Record 9 of Set 6 | zhanaozen
# Processing Record 10 of Set 6 | nouakchott
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | chama
# Processing Record 13 of Set 6 | maniitsoq
# Processing Record 14 of Set 6 | thompson
# Processing Record 15 of Set 6 | lossiemouth
# Processing Record 16 of Set 6 | shubarkuduk
# Processing Record 17 of Set 6 | bay roberts
# Processing Record 18 of Set 6 | southbridge
# City not found. Skipping...
# Processing Record 19 of Set 6 | port hedland
# Processing Record 20 of Set 6 | yar-sale
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | thinadhoo
# Processing Record 23 of Set 6 | kahului
# Processing Record 24 of Set 6 | yarada
# Processing Record 25 of Set 6 | itaituba
# Processing Record 26 of Set 6 | maceio
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | miles city
# Processing Record 29 of Set 6 | hami
# Processing Record 30 of Set 6 | matay
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | neuhof
# Processing Record 33 of Set 6 | vega de alatorre
# Processing Record 34 of Set 6 | sangar
# Processing Record 35 of Set 6 | teguise
# Processing Record 36 of Set 6 | itarema
# Processing Record 37 of Set 6 | ardakan
# Processing Record 38 of Set 6 | oksfjord
# Processing Record 39 of Set 6 | bolu
# City not found. Skipping...
# Processing Record 40 of Set 6 | cherskiy
# Processing Record 41 of Set 6 | facatativa
# Processing Record 42 of Set 6 | lodja
# Processing Record 43 of Set 6 | port-gentil
# Processing Record 44 of Set 6 | broome
# Processing Record 45 of Set 6 | port blair
# Processing Record 46 of Set 6 | zaporizhzhya
# Processing Record 47 of Set 6 | vila velha
# Processing Record 48 of Set 6 | upernavik
# Processing Record 49 of Set 6 | vila
# Processing Record 50 of Set 6 | astoria
# Processing Record 0 of Set 7 | chantada
# Processing Record 1 of Set 7 | lidkoping
# City not found. Skipping...
# Processing Record 2 of Set 7 | ouadda
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | vieira de leiria
# Processing Record 5 of Set 7 | paita
# Processing Record 6 of Set 7 | zhaotong
# City not found. Skipping...
# Processing Record 7 of Set 7 | ushirombo
# Processing Record 8 of Set 7 | whitefish
# Processing Record 9 of Set 7 | jian
# Processing Record 10 of Set 7 | tazovskiy
# Processing Record 11 of Set 7 | katherine
# Processing Record 12 of Set 7 | fukue
# Processing Record 13 of Set 7 | talaya
# Processing Record 14 of Set 7 | dumas
# City not found. Skipping...
# Processing Record 15 of Set 7 | oktyabrskoye
# Processing Record 16 of Set 7 | corn island
# Processing Record 17 of Set 7 | te anau
# City not found. Skipping...
# Processing Record 18 of Set 7 | haukipudas
# City not found. Skipping...
# Processing Record 19 of Set 7 | sohag
# Processing Record 20 of Set 7 | katsuura
# Processing Record 21 of Set 7 | zeya
# City not found. Skipping...
# Processing Record 22 of Set 7 | kameyama
# Processing Record 23 of Set 7 | cidreira
# Processing Record 24 of Set 7 | hede
# Processing Record 25 of Set 7 | muroto
# Processing Record 26 of Set 7 | izhma
# Processing Record 27 of Set 7 | sao paulo de olivenca
# Processing Record 28 of Set 7 | fortuna
# City not found. Skipping...
# Processing Record 29 of Set 7 | niceville
# Processing Record 30 of Set 7 | springbok
# Processing Record 31 of Set 7 | kloulklubed
# City not found. Skipping...
# Processing Record 32 of Set 7 | kimbe
# Processing Record 33 of Set 7 | surovikino
# Processing Record 34 of Set 7 | papara
# City not found. Skipping...
# Processing Record 35 of Set 7 | caravelas
# Processing Record 36 of Set 7 | goroka
# Processing Record 37 of Set 7 | oranjestad
# Processing Record 38 of Set 7 | mengcheng
# Processing Record 39 of Set 7 | yate
# Processing Record 40 of Set 7 | calama
# City not found. Skipping...
# Processing Record 41 of Set 7 | arman
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 7 | minsk
# Processing Record 43 of Set 7 | yerofey pavlovich
# Processing Record 44 of Set 7 | iralaya
# Processing Record 45 of Set 7 | dandong
# Processing Record 46 of Set 7 | saint anthony
# City not found. Skipping...
# Processing Record 47 of Set 7 | abreus
# Processing Record 48 of Set 7 | gravdal
# Processing Record 49 of Set 7 | sioux lookout
# Processing Record 50 of Set 7 | puerto narino
# Processing Record 0 of Set 8 | tual
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | callaguip
# Processing Record 3 of Set 8 | ingham
# City not found. Skipping...
# Processing Record 4 of Set 8 | ankara
# Processing Record 5 of Set 8 | roald
# Processing Record 6 of Set 8 | nalut
# City not found. Skipping...
# Processing Record 7 of Set 8 | bud
# Processing Record 8 of Set 8 | kavaratti
# Processing Record 9 of Set 8 | ponta delgada
# Processing Record 10 of Set 8 | araouane
# Processing Record 11 of Set 8 | taoudenni
# Processing Record 12 of Set 8 | westport
# Processing Record 13 of Set 8 | san cristobal
# Processing Record 14 of Set 8 | east wenatchee bench
# Processing Record 15 of Set 8 | kayes
# Processing Record 16 of Set 8 | luena
# Processing Record 17 of Set 8 | coihaique
# Processing Record 18 of Set 8 | alyangula
# Processing Record 19 of Set 8 | severo-yeniseyskiy
# Processing Record 20 of Set 8 | bhadasar
# City not found. Skipping...
# Processing Record 21 of Set 8 | okahandja
# Processing Record 22 of Set 8 | warragul
# Processing Record 23 of Set 8 | dingle
# Processing Record 24 of Set 8 | hobyo
# Processing Record 25 of Set 8 | acari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 8 | idaho falls
# Processing Record 27 of Set 8 | taltal
# Processing Record 28 of Set 8 | dudinka
# Processing Record 29 of Set 8 | iqaluit
# Processing Record 30 of Set 8 | priboj
# Processing Record 31 of Set 8 | wajir
# Processing Record 32 of Set 8 | umm lajj
# Processing Record 33 of Set 8 | mogocha
# Processing Record 34 of Set 8 | tanete
# Processing Record 35 of Set 8 | lyuban
# Processing Record 36 of Set 8 | kaohsiung
# Processing Record 37 of Set 8 | surt
# Processing Record 38 of Set 8 | havre-saint-pierre
# Processing Record 39 of Set 8 | bandarbeyla
# Processing Record 40 of Set 8 | ceres
# Processing Record 41 of Set 8 | harper
# Processing Record 42 of Set 8 | umba
# Processing Record 43 of Set 8 | lagoa
# City not found. Skipping...
# Processing Record 44 of Set 8 | hay river
# Processing Record 45 of Set 8 | mae hong son
# Processing Record 46 of Set 8 | lazurne
# Processing Record 47 of Set 8 | aquiraz
# Processing Record 48 of Set 8 | pontes e lacerda
# Processing Record 49 of Set 8 | cockburn town
# Processing Record 50 of Set 8 | fairbanks
# Processing Record 0 of Set 9 | galle
# Processing Record 1 of Set 9 | hastings
# Processing Record 2 of Set 9 | eresos
# Processing Record 3 of Set 9 | haverfordwest
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 9 | coquimbo
# Processing Record 5 of Set 9 | bonavista
# Processing Record 6 of Set 9 | buala
# Processing Record 7 of Set 9 | razdolinsk
# Processing Record 8 of Set 9 | abu dhabi
# Processing Record 9 of Set 9 | aklavik
# Processing Record 10 of Set 9 | poum
# Processing Record 11 of Set 9 | eregli
# Processing Record 12 of Set 9 | boa vista
# City not found. Skipping...
# Processing Record 13 of Set 9 | pyaozerskiy
# Processing Record 14 of Set 9 | san jeronimo
# Processing Record 15 of Set 9 | vangaindrano
# Processing Record 16 of Set 9 | salinas
# Processing Record 17 of Set 9 | tocopilla
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | edd
# Processing Record 20 of Set 9 | marawi
# Processing Record 21 of Set 9 | talnakh
# Processing Record 22 of Set 9 | kutum
# Processing Record 23 of Set 9 | tevriz
# Processing Record 24 of Set 9 | tiarei
# Processing Record 25 of Set 9 | gilgit
# Processing Record 26 of Set 9 | iracoubo
# City not found. Skipping...
# Processing Record 27 of Set 9 | owando
# City not found. Skipping...
# Processing Record 28 of Set 9 | wahpeton
# Processing Record 29 of Set 9 | iwanai
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | jacareacanga
# Processing Record 32 of Set 9 | zhangzhou
# Processing Record 33 of Set 9 | nyurba
# Processing Record 34 of Set 9 | aguimes
# Processing Record 35 of Set 9 | itacarambi
# Processing Record 36 of Set 9 | lethem
# Processing Record 37 of Set 9 | zabaykalsk
# Processing Record 38 of Set 9 | asyut
# Processing Record 39 of Set 9 | ulaangom
# City not found. Skipping...
# Processing Record 40 of Set 9 | trinidad
# Processing Record 41 of Set 9 | vidim
# Processing Record 42 of Set 9 | srandakan
# Processing Record 43 of Set 9 | ust-tsilma
# Processing Record 44 of Set 9 | tutoia
# Processing Record 45 of Set 9 | bouar
# Processing Record 46 of Set 9 | sambava
# Processing Record 47 of Set 9 | tomatlan
# Processing Record 48 of Set 9 | iquique
# Processing Record 49 of Set 9 | ko samui
# Processing Record 50 of Set 9 | middlebury
# Processing Record 0 of Set 10 | nanortalik
# Processing Record 1 of Set 10 | cossato
# Processing Record 2 of Set 10 | acobamba
# Processing Record 3 of Set 10 | leningradskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | konyshevka
# Processing Record 5 of Set 10 | shizunai
# Processing Record 6 of Set 10 | notre-dame-du-lac
# Processing Record 7 of Set 10 | ternate
# Processing Record 8 of Set 10 | windhoek
# Processing Record 9 of Set 10 | nioro
# Processing Record 10 of Set 10 | agadez
# Processing Record 11 of Set 10 | tuatapere
# Processing Record 12 of Set 10 | teya
# Processing Record 13 of Set 10 | constitucion
# Processing Record 14 of Set 10 | nemuro
# Processing Record 15 of Set 10 | port lincoln
# Processing Record 16 of Set 10 | salo
# Processing Record 17 of Set 10 | mounana
# Processing Record 18 of Set 10 | boyolangu
# Processing Record 19 of Set 10 | south yarmouth
# Processing Record 20 of Set 10 | tilhar
# Processing Record 21 of Set 10 | monroe
# Processing Record 22 of Set 10 | beira
# Processing Record 23 of Set 10 | ust-kut
# Processing Record 24 of Set 10 | calvinia
# Processing Record 25 of Set 10 | sayyan
# Processing Record 26 of Set 10 | praya
# Processing Record 27 of Set 10 | tudela
# Processing Record 28 of Set 10 | keti bandar
# Processing Record 29 of Set 10 | oktyabrskiy
# Processing Record 30 of Set 10 | zhigansk
# Processing Record 31 of Set 10 | tungor
# Processing Record 32 of Set 10 | kano
# Processing Record 33 of Set 10 | cabo rojo
# Processing Record 34 of Set 10 | floro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 10 | iquitos
# Processing Record 36 of Set 10 | salalah
# Processing Record 37 of Set 10 | nadadores
# Processing Record 38 of Set 10 | clyde river
# Processing Record 39 of Set 10 | ulladulla
# Processing Record 40 of Set 10 | kupang
# City not found. Skipping...
# Processing Record 41 of Set 10 | arcata
# Processing Record 42 of Set 10 | ucluelet
# City not found. Skipping...
# Processing Record 43 of Set 10 | okha
# Processing Record 44 of Set 10 | polyarnyy
# Processing Record 45 of Set 10 | tilichiki
# City not found. Skipping...
# Processing Record 46 of Set 10 | fauske
# Processing Record 47 of Set 10 | madingou
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# convert to data frame 
weather_df = pd.DataFrame(weather_data)

# display data frame
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        yichun          24      CN  1551471160        53  47.72  128.88
# 1  punta arenas          75      CL  1551470594        87 -53.16  -70.91
# 2         kapaa          90      US  1551470907        46  22.08 -159.32
# 3     byron bay          75      AU  1551471019        94 -28.65  153.62
# 4     mahebourg          75      MU  1551470941        83 -20.41   57.70
#
#    Max Temp  Wind Speed
# 0       3.0        2.06
# 1      55.4        8.05
# 2      73.4       11.41
# 3      69.8        9.17
# 4      82.4        9.17

# %%
weather_df.count()
# Out:
# City          506
# Cloudiness    506
# Country       506
# Date          506
# Humidity      506
# Lat           506
# Lng           506
# Max Temp      506
# Wind Speed    506
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# export the city data into csv
weather_df.to_csv("output/weather_data.csv", encoding='utf-8', index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Max Temp"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# set y limits and grids
plt.ylim(0,105)
plt.grid(True)

# save figure
plt.savefig("images/LattitudeVsTemp.png")

# display the figure
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Humidity"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# set y limits and grids
plt.ylim(0,105)
plt.grid(True)

# save figure
plt.savefig("images/LatitudeVsHumidity.png")

# display the figure
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Cloudiness"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# set y limits and grids
plt.ylim(0,105)
plt.grid(True)

# save figure
plt.savefig("images/LatitudeVsCloudiness.png")

# display the figure
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# scatter plot
plt.scatter(weather_df["Lat"],weather_df["Wind Speed"], marker="o", alpha=0.75, edgecolor="black")

# print title and labels
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# set y limits and grids
plt.ylim(0,35)
plt.grid(True)

# save figure
plt.savefig("images/LatitudeVsWindSpeed.png")

# display the figure
plt.show()
